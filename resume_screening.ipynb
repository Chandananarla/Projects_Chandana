# %% [markdown]
# # AIT-590 : INTRO TO NLP
#
# # FINAL PROJECT - RESUME SCREENING
#
# By:
#    01 - TEAM 01 (SHRAVYA GADDAM,CHANDANA NARLA, ANIRUDH TUNUGUNTLA)

# %%
import sys
import re
import requests
import bs4
import csv
import os
import datetime
import math
import nltk

from bs4 import BeautifulSoup
from nltk import ngrams
from nltk.corpus import stopwords  
from gensim import similarities
from gensim import models
from gensim import corpora
from datetime import datetime
from nltk.tokenize import word_tokenize, sent_tokenize, WordPunctTokenizer

# %%
#This function takes skills of a role in corpus as input , and returns them in form of list of tuples
# ex: input :"<Skills>(HTML,Hypertext Markup Language), (Cascading Style Sheets,CSS), (SQL, Structured Query Language)</Skills>"
#    output :[(HTML,Hypertext Markup Language), (Cascading Style Sheets,CSS), (SQL, Structured Query Language)]
# Regular expression and string functions like: split(), strip(), replace(), lower() are used to achieve this conversion
def format_skills_corpus(job_skills):
    match = re.search(r'\((\.|\s|\w+)?\,(\.|\s|\w+)*?\)',job_skills,re.M|re.I)
    if match is None:
        job_skills = job_skills.strip('\n').strip().split(',')
    else:    
        job_skills = job_skills.strip('\n').strip().split('),')
    job_skills = [skill.strip().replace('(','').replace(')','') for skill in job_skills]
    job_skills = [skill.lower().split(',') for skill in job_skills]
    return job_skills

#This function takes other tags data of a role in corpus as input and returns them in form of list 
# ex: input: "Computer Science, Computer Programming, Computer Engineering" 
#     output: ['Computer Science', ' Computer Programming', ' Computer Engineering']
def format_corpus(file_data):
    formated_data = file_data.string.strip('\n').strip().split(',')
    return formated_data

# This function takes the formated corpus data and required job_role as input
# and returns the formatted data of Skills, Education and Work Experience for the given job role in form of dictionary
def get_jobrole_corpus(corpus_data,job_role):
    role_data_dic = dict()
    roledata = corpus_data.find(job_role)
    print("role",job_role)
    role_skill_data = roledata.find('Skills')
    print(role_skill_data)
    role_skills = format_skills_corpus(role_skill_data.string)
    role_education = roledata.find('Education')
    role_education = format_corpus(role_education.string)
    role_experience = roledata.find('Experience')
    role_experience = format_corpus(role_experience.string)
    role_data_dic['Skills'] = role_skills
    role_data_dic['Education'] = role_education
    role_data_dic['Experience'] = role_experience
    return role_data_dic
# This function reads the corpus file and returns a dictionary containing require dcorpus data for each role
def get_corpus_data():
    JObRole = open("job_roles.xml","r",encoding="utf8")
    jobdata= JObRole.read()
    jobrole_data = bs4.BeautifulSoup(jobdata, 'lxml-xml')
    job_roles = jobrole_data.corpus.children
    corpus_data_dic = dict()
    for role in job_roles:
        if role.name!=None:
            #print("role name-",role.name)
            role_dic = get_jobrole_corpus(jobrole_data,role.name)
            corpus_data_dic[role.name] = role_dic
    return corpus_data_dic

# %%
# this function gets the url of the candidate and returns it.
# this the link to the candidates resume
# it taks th eurl object as input
def get_candidate_url(url):
    resumeurls=url.get('href')
    return resumeurls
# this function takes the bs4 object for the candidates page as input 
# and returns the candidates Name 
def get_candidate_name(indvisoup):
    CandidateName=[]
    d1=indvisoup.find('div')
    CandidateName=d1.find("h1").get_text()
    return CandidateName

# this function takes the bs4 object for the candidates page as input 
# and returns the candidates skills/keywords in form of a list
def get_candidate_skills(indvisoup):
    SkillsSet = []
    for d1 in indvisoup.find_all('li'): 
        Skill=d1.get_text()
        if(Skill=='FAQ'):
            break;
        SkillsSet.append(Skill)
        #print(SkillsSet)
    return SkillsSet

# this function takes the bs4 object for the candidates page as input 
# and returns the candidates work experience in form of list of tuples containing, role & duration details
def get_candidate_experience(indvisoup):
    WorkExperience=[]
    for d1 in indvisoup.find_all(id='work_experience'):
        for d2 in d1.find_all('tr'):
            row = []
            for c2 in d2.find_all('td'):
                if c2 is not None:
                    d3=c2.get_text().strip()
                    row.append(d3)
            WorkExperience.append(tuple(row))
    return WorkExperience

# this function takes the bs4 object for the candidates page as input 
# and returns the education details in form of list of tuples containing program name, year and type of degree 
def get_candidate_education(indvisoup):
    Education=[]
    for d1 in indvisoup.find_all(id='education'): 
        for d2 in d1.find_all('tr'):
            row = []
            for c2 in d2.find_all('td'):
                if c2 is not None:
                    d3=c2.get_text().strip()
                    row.append(d3)
            Education.append(tuple(row))
    return Education

# this function takes the bs4 object for the candidates page as input 
# and returns the candidates details like current occupaltion , location, willing to relocate etc.,
# in form of dictionary
def get_candidate_profile_data(indvisoup):
    profile_data = dict()
    d1 = indvisoup.select("table.resume_module_table > tr")
    if len(d1)==0:
        return profile_data
    data = d1[0].get_text().strip().replace(' ','').replace('\r','').replace('\n',' ')
    data = data.split('  ')
    print(data)
    for ele in data:
        match = re.match(r'(.*):(.*)',ele,re.M|re.I)
        if match is not None:
            try:
                key = match.group(1)
                val = match.group(2)
                profile_data[key.strip()]=val.strip()
            except:
                continue
    return profile_data

# %%
# This function takes the skills of a role from corpus and list of skills of the user
# and returns score for the user by checking the similarty between the given lists of skills
# Here the corpus dictionary is built based on the user skills,
# which is converted into bag of words using gensim corpora dictionary & dictionary's doc2bow function.
# Then tfidf model is built using gensim models - TfidfModel function based on the bowcorpus built earlier.
# Then using SparseMatrixSimilarity function if gensim similarities module index is built using the tfidf model & feature_count of the dictionary
# Also a base dictionary with skills from required as keys and values as False is created,
# for which the value is set to True if the similarity % obtained using the above created index is matched,
# this way any duplicate matches are eliminated while calculating the score
# Count of the skills which of Trues is noted and then divided by the total number of required skills
# and the obtained value is returned as the skills score for the user for the given role.

def get_skill_score(userSkills, roleReqSkills):
    processd_corpus = [[word for word in document.lower().split()]
         for document in userSkills]
    #print(processd_corpus)
    similarity_dict = dict()
    for req_skill in roleReqSkills:
        temp = ','.join(req_skill)
        similarity_dict[temp] = False
        
    dictionary = corpora.Dictionary(processd_corpus)
    feature_count = len(dictionary.token2id)
    bow_corpus = [dictionary.doc2bow(text) for text in processd_corpus]
    tfidf = models.TfidfModel(bow_corpus)
    index = similarities.SparseMatrixSimilarity(tfidf[bow_corpus], num_features=feature_count)
    for reqSkill in roleReqSkills:
        query_bow = dictionary.doc2bow(reqSkill)
        sims = index[tfidf[query_bow]]
        sorted_similarity = sorted(enumerate(sims), key=lambda x: x[1], reverse=True)
        if sorted_similarity[0][1]>=0.70:
            temp = ','.join(reqSkill)
            similarity_dict[temp] = True
    count = 0
    for reqskill in similarity_dict.keys():
        if similarity_dict[reqskill]:
            count += 1
    return count/len(roleReqSkills)

# %%
# this function takes list of job roles accepted for a specific role and the work experience details of the user
# Using gensim corpora for dictionary, doc2bow and gensims models -> tfidfmodel a model is built
# on which gensim similarities -> sparse similarity matrix is applied , which is used to look for similarities
# between required job roles & user's job role.
# if the job role of user's experience is similar to the required ones, 
# then the duration of the particular experience is calculated by using the start & and end dates given
# duration of all these relevant experiences is summed up to get the user's total relevant experience
# then score is assigned to user based on this duration.
# if the total experience is betweeon 0-3 years then a score of 1 is assigned,
# if the experience is between 3-5 years then a score of 2 is assigned,
# if the experience is between 5-10 years then a score of 3 is assigned, 
# if the experience is > 10 years then a score of 4 is assigned,
# if the user has no relevant experience then a score of 0 is assigned.
# and this score divided by the highest possible score of 4 is returned.
def get_work_experience_score(jobroles, user_experience):
    processd_corpus = [[word for word in document.lower().split()] for document in jobroles]
    dictionary = corpora.Dictionary(processd_corpus)
    feature_count = len(dictionary.token2id)
    bow_corpus = [dictionary.doc2bow(text) for text in processd_corpus]
    tfidf = models.TfidfModel(bow_corpus)
    index = similarities.SparseMatrixSimilarity(tfidf[bow_corpus], num_features=feature_count)
    master_count = 0
    bachelor_count = 0
    phd_count = 0
    total_expr = 0
    for work_expr in user_experience:
        if(len(work_expr)<2):
            continue
        jobrole = work_expr[0].lower().split()
        job_duration = work_expr[1]
        query_bow = dictionary.doc2bow(jobrole)
        sims = index[tfidf[query_bow]]
        sorted_similarity = sorted(enumerate(sims), key=lambda x: x[1], reverse=True)
        if sorted_similarity[0][1]>=0.70:
            job_duration = job_duration.strip()
            dates = job_duration.strip().split('-')
            dates = [date.strip() for date in dates]
            try:
                startdate = datetime.strptime(dates[0],'%m/%Y')
            except:
                try:
                    startdate = datetime.strptime(dates[0],'/%Y')
                except:
                    startdate = ''
            enddate = dates[1]
            if enddate !='Present':
                try:
                    enddate = datetime.strptime(enddate,'%m/%Y')
                except:
                    try:
                        enddate = datetime.strptime(enddate,'/%Y')
                    except:
                        enddate = ''
            else:
                enddate = datetime.now()
            if enddate=='' or startdate=='':
                total_expr = 0
            else:
                duration = enddate-startdate
                total_expr = duration.days/365
    work_score = 0
    if(total_expr>0 and total_expr<3):
        work_score = 1
    elif total_expr>=3 and total_expr<5:
        work_score = 2
    elif total_expr>=5 and total_expr<10:
        work_score = 3
    elif total_expr>10:
        work_score = 4
    else:
        work_score = 0
    return work_score/4

# %%
# This function takes related education majors from corpus and candidates education details as input
# and returns candidate's education score.
# If the major of the candidate's degree matches with atleast one given in the corpus then it is considered
# For the matched educaton, then degree level counts are calculated. it maintain 3 count variables for each degree level (PHD, Masters, Bachelors)
# i.e., suppose a candidate has total 4 degrees.
# 2 masters degrees, 1 PHD and 1 bachelors degree
# And suppose of these degrees , 1 masters , 1 phd are relevent to the job role and remaining are not relevant
# In such case the count variables are updated only with the count of relevant degrees ie.,
# bachelor_count = 0, master_count = 1, phd_count = 1 will be assigned
# After all the degrees of candidate are verfied for specific role then , 
# score is allocated to candidate based on these counts:
# First the candidate's phdcount is checked, if it is greater than 1 then score of 5 is assigned (hihghest)
# else if the candidate has only 1 phd degree then a score of 4 is assigned, 
# if the candidate's phd_count is 0 then the candidates master_scount is considered.
# Here if the candidate has master_count>1 then score of 3 assigned , 
# else if the candidate has only 1 masters degree then a score of 2 is assigned,
# else if the candidate master_count is 0, then bachelor_count is checked.
# if the candidate has atleast one bachelor degree then score of 1 is assigned 
# else the score of the candidate remains 0
# Only the highest degree level of relevant education is considered.
# Here the highest score possible for a user is 5.
# Finally the percentage of the education score is returned as the education score. ie., 
# the value of the score assigned divided by the max score - 5 is returned.
def get_education_score(jobrole_majors, user_education):
    processd_corpus = [[word for word in document.lower().split()] for document in jobrole_majors]
    dictionary = corpora.Dictionary(processd_corpus)
    feature_count = len(dictionary.token2id)
    bow_corpus = [dictionary.doc2bow(text) for text in processd_corpus]
    tfidf = models.TfidfModel(bow_corpus)
    index = similarities.SparseMatrixSimilarity(tfidf[bow_corpus], num_features=feature_count)
    master_count = 0
    bachelor_count = 0
    phd_count = 0
    for education in user_education:
        if(len(education)<3):
            continue
        major = education[0].lower().split()
        degree_level = education[2]
        query_bow = dictionary.doc2bow(major)
        sims = index[tfidf[query_bow]]
        sorted_similarity = sorted(enumerate(sims), key=lambda x: x[1], reverse=True)
        if sorted_similarity[0][1]>=0.70:
            if 'Master' in degree_level:
                master_count += 1
            elif 'Bachelor' in degree_level:
                bachelor_count += 1
            elif 'PHD' in degree_level or 'Post Graduation' in degree_level or 'Doctorate' in degree_level:
                phd_count += 1
            else:
                sc = 0
                
    edu_score = 0
    if phd_count>0:
        if phd_count>1:
            edu_score = 5
        else:
            edu_score = 4
    else:
        if master_count>0:
            if master_count > 1:
                edu_score = 3
            else:
                edu_score = 2
        elif bachelor_count > 0:
            edu_score = 1
    return edu_score/5

# %%
# This function takes, each role required data from corpus and the candidate's data as input arguments
# And returns the overall score of the candidate for given role.
# get_skill_score, get_education_score, get_work_experience_score are used to get the respective scores.
# these 3 scores are used to calculate the overall score for given role for the candidate,
# Overall score is the sum of weighted score of these individual scores.
# Overall score = 55% of skill score, 30% workexperience score & 15% education score
# This calculated value percent is returned ad the candidate's score for the given role.
def get_role_score(role_corpus,candidate_details):
    role_skills_corpus= role_corpus['Skills']
    role_education_corpus = role_corpus['Education']
    role_experience_corpus = role_corpus['Experience']
    candidate_SkillsSet= candidate_details['Skills']
    candidate_education = candidate_details['Education']
    candidate_experience = candidate_details['Experience']
    if len(candidate_SkillsSet)!=0:
        skills_score = get_skill_score(candidate_SkillsSet,role_skills_corpus)
    else:
        skills_score = 0.0
    if len(candidate_education)!=0:
        education_score = get_education_score(role_education_corpus,candidate_education)
    else:
        education_score = 0
    if len(candidate_experience)!=0:
        experience_score = get_work_experience_score(role_experience_corpus,candidate_experience)
    else:
        experience_score = 0
    total_score = 0.55*skills_score+0.15*education_score+0.30*experience_score
    total_score_percentage = total_score*100
    return total_score_percentage

# %%
# This block of code is the main part of the project. 
# This is where the actual execution starts.

# Here the get_corpus_data function is used to get the required skillset, education & workexperience details for each role in corpus.
corpus_data_dic = get_corpus_data()
# Here a csv file is created to write all the results into it and header of the file is set based on the roles in the corpus file
# Also result_writer object is created using which the result for each candidate are wriiten into the csv file.
result_file = open('Candidate_Resume_scores.csv','w',newline='')
Columns = ['Name','Occupation','WillRelocate','Location','EducationLevel','Resume_Link']
for key in corpus_data_dic.keys():
    temp = key+'_score'
    Columns.append(temp)
    temp = key+'_picked'
    Columns.append(temp)
result_writer = csv.DictWriter(result_file, fieldnames = Columns)
result_writer.writeheader()

for key in corpus_data_dic.keys():
    print(key,":",corpus_data_dic[key])
    
total_role_sum_dic = dict()
try:
    # here using requests we get the url content of climbers site in which resumes are listed.
    resumesource=requests.get("https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/i/Information-Technology")
    # the url content obtained is then parsed using Beautiful soup
    # this page contains links to list of resumes of different roles
    resumesoup=BeautifulSoup(resumesource.text,'html.parser')
    for url in resumesoup.find_all('td'):
        url=url.find('h3')
        if url is not None:
            for department_url in url.find_all('a'):
                urlcount=department_url.get_text()
                resumeurls=department_url.get('href')
                # here the page content of each job role in the website is retrieved.
                # it contains list of candidate resumes of that particular dept/role/occupation
                department_source=requests.get(resumeurls)
                # here also we use beautofu soup get links of each candidate's resume
                department_soup=BeautifulSoup(department_source.text,'html.parser')
                # we iterate for each candidate, extract details from candidate's resume,
                # calculate scores and write the result into a temporary file
                for values in department_soup.find_all('h2'):
                    for url1 in values.find_all('a'):
                        print('*********')
                        candidate_details = dict()
                        score_details = dict()
                        # here url - link to canidate's resume is stored.
                        ResumeDetails = get_candidate_url(url1)
                        print(ResumeDetails)
                        candidate_details['Resume_Link']=ResumeDetails
                        indvisource=requests.get(ResumeDetails)
                        indvisoup=BeautifulSoup(indvisource.text,'html.parser')
                        #here Candidate Name is extracted 
                        CandidateName=get_candidate_name(indvisoup)
                        print(CandidateName)
                        candidate_details['Name']=CandidateName
                        #Here the candidate's profile data like currect location, occupation, willing to relocate are extracted
                        profile_data = get_candidate_profile_data(indvisoup)
                        candidate_details.update(profile_data)
                        #here the candidate's skillset/keywords are extracted
                        SkillsSet = get_candidate_skills(indvisoup)
                        score_details['Skills']=SkillsSet
                        #here the candidate's Work Experience details are extracted
                        WorkExperience=get_candidate_experience(indvisoup)
                        score_details['Experience']=WorkExperience
                        #here the candidate's Education details are extracted         
                        Education=get_candidate_education(indvisoup)
                        # all the candidate's details extracted are stored in from of dictionary
                        score_details['Education']=Education                
                        candidate_rolewise_scores = dict()
                        # for each role in the corpus, candidat'e overall score's are calculated and stored            
                        for corpus_role in corpus_data_dic.keys():
                            role_corpus = corpus_data_dic[corpus_role]
                            total_role_score = get_role_score(role_corpus,score_details)
                            candidate_rolewise_scores[corpus_role] = total_role_score
                            print("role:",corpus_role,",score:",total_role_score)
                            key = corpus_role+'_score'
                            # here the sum of scores of all the candidates for each role is calculated and stored
                            # this is later used to find average score which is later used inorder set the cutoff.
                            candidate_details[key]=total_role_score
                            try:
                                if profile_data['Occupation']==corpus_role:
                                    if corpus_role in total_role_sum_dic.keys():
                                        tempsum = total_role_sum_dic[corpus_role][0]+total_role_score
                                        count = total_role_sum_dic[corpus_role][1] + 1
                                        total_role_sum_dic[corpus_role] = (tempsum,count) 
                                    else:
                                        total_role_sum_dic[corpus_role] = (total_role_score,1)
                            except KeyError:
                                continue
                                
                        # here the candidate's details along with his scores and whether screened for the given roles is written into the csv file    
                        result_writer.writerow(candidate_details)

finally:
    # in this block of code, based on the previously calculated scores,
    # each resume is screened based of the cutoff calculated, 
    # which is about 1.5 times the overall average score.
    # if the candidate's core is greater than this value then his resume is selected
    # which is represented by 'YES' value in the picked column of perticular role
    # This selection is updated into the csv file
    result_file.close()
    total_role_avg = dict()
    try:
        read_file = open('Candidate_Resume_Scores.csv','r')
        result_file = open('Candidate_Resume_Screened.csv','w',newline='')
        
        reader = csv.DictReader(read_file)
        writer = csv.DictWriter(result_file, fieldnames=Columns)
        writer.writeheader()
        for role in total_role_sum_dic.keys():
            total_role_avg[role] =  total_role_sum_dic[corpus_role][0]/total_role_sum_dic[corpus_role][1] 
        for row in reader:
            data_row = row
            for role in total_role_sum_dic.keys():
                key = role+'_score'
                act_key = role+'_picked'
                if float(row[key])>=total_role_avg[role]*1.5:
                    data_row[act_key] = 'YES'
                else:
                    data_row[act_key] = 'NO'
            writer.writerow(data_row)
        
    finally:
        #finally the resultant file is closed so the results are saved.
        read_file.close()
        os.remove('Candidate_Resume_Scores.csv')
        result_file.close()
# Out:
# role WebDeveloper
# <Skills>(HTML,Hypertext Markup Language), (Cascading Style Sheets,CSS), (SQL, Structured Query Language), (PHP,Hypertext Preprocessor), (Javascript), (Python), (Laravel), (Django), (Angular,AngularJS), (ReactJS, React), (JQuery),(.NET,ASP.NET),(Ruby),(Node.js)
#     </Skills>
# role DataMiningSpecialist
# <Skills>R, Python, Java, SQL, Scala, SAS, NoSQL, Databox, Zoho Analytics,Google Chart, Tableau, Power BI, Qlikview, Apache Spark, Excel, SAP, TIBCO, Grafana, WEKA, Hadoop,HIVE, HDFS, Highcharts, D3, Fusion chart, Canvas, nltk, pandas, numpy, MATLAB, Logistic Regression,Linear Regression, Gradient Boost, (SVM,Support Vector Machine), Naive Bayes, (K nearest neighbor,KNN), Neural Network, Natural Language Processing, Clustering, Classification, Big Data, MapReduce, Machine Learning, (ETL,Extraction Transformation and Loading)
#     </Skills>
# role DatabaseAdministrator
# <Skills>SQL, MySQL, TSQL, PLSQL, Oracle, Microsoft SQL Server, IBM, MongoDB, Cassandra, Salesforce, PostgreSQL, Database Queries, Theory, Design, RDBMS, Distributed Computing Architectures, REST, ODBC, JDBC, SQLJ, Java EE, .NET
#     </Skills>
# role Tester
# <Skills>Java, Python, C#, Javascript, Ruby, PHP, Groovy, VBScript, Selenium, Appium, Cucumber, Robot Framework , Watir, Katalon, SOAP UI, JMeter, UFT
#     </Skills>
# role TeamLeader
# <Skills>
#         Project Management, Software Development, Software Architecture and Design, Key Account Management, Customer Success, Software-as-a-Service, Client Service, Business Development, Renewal Management, EDI, Electronic Data Interchange, ERP Systems, File Transfer Protocol, COBOL, EDI
#     </Skills>
# role NetworkAdministrator
# <Skills>
#         IP Network Address Design, Cisco Routers, Cisco IOS / CAT Switches, Cisco Nexus (NX-OS) Switches, WAN Provisioning, IP Routing, ATM Ox, Service Provider Routing, HSRP, VRRP, GLBP, Cisco VSS, Hosted VoIP, F5 Load Balancer LTM, Juniper SRX, MPLS and MPLS VPN
#     </Skills>
# WebDeveloper : {'Skills': [['html', 'hypertext markup language'], ['cascading style sheets', 'css'], ['sql', ' structured query language'], ['php', 'hypertext preprocessor'], ['javascript'], ['python'], ['laravel'], ['django'], ['angular', 'angularjs'], ['reactjs', ' react'], ['jquery'], ['.net', 'asp.net'], ['ruby'], ['node.js']], 'Education': ['Computer Science', ' Computer Programming', ' Computer Engineering', ' Information Technology', ' Software Engineering'], 'Experience': ['Web Developer', ' Web Designer', ' Front End', ' UI Designer', ' UX Designer', ' Full Stack']}
# DataMiningSpecialist : {'Skills': [['r', ' python', ' java', ' sql', ' scala', ' sas', ' nosql', ' databox', ' zoho analytics', 'google chart', ' tableau', ' power bi', ' qlikview', ' apache spark', ' excel', ' sap', ' tibco', ' grafana', ' weka', ' hadoop', 'hive', ' hdfs', ' highcharts', ' d3', ' fusion chart', ' canvas', ' nltk', ' pandas', ' numpy', ' matlab', ' logistic regression', 'linear regression', ' gradient boost', ' svm', 'support vector machine'], ['naive bayes', ' k nearest neighbor', 'knn'], ['neural network', ' natural language processing', ' clustering', ' classification', ' big data', ' mapreduce', ' machine learning', ' etl', 'extraction transformation and loading']], 'Education': ['Data Science', ' Data Analytics', ' Statistical and Data Science', ' Computer Science', ' Predictive Analytics', ' Big Data Analytics'], 'Experience': ['Data Analyst', ' Data Scientist', ' Data Engineer', ' Business Intelligence Analyst']}
# DatabaseAdministrator : {'Skills': [['sql'], ['mysql'], ['tsql'], ['plsql'], ['oracle'], ['microsoft sql server'], ['ibm'], ['mongodb'], ['cassandra'], ['salesforce'], ['postgresql'], ['database queries'], ['theory'], ['design'], ['rdbms'], ['distributed computing architectures'], ['rest'], ['odbc'], ['jdbc'], ['sqlj'], ['java ee'], ['.net']], 'Education': ['Computer Science', ' Information Science', ' Information Systems', ' Management of Information Systems'], 'Experience': ['Systems DBA', ' Database Analyst', ' Application DBA', ' Database Architect', ' Data Warehouse administrator', ' Database Administrator', ' Cloud DBA']}
# Tester : {'Skills': [['java'], ['python'], ['c#'], ['javascript'], ['ruby'], ['php'], ['groovy'], ['vbscript'], ['selenium'], ['appium'], ['cucumber'], ['robot framework'], ['watir'], ['katalon'], ['soap ui'], ['jmeter'], ['uft']], 'Education': ['Electrical Engineering', ' Information Technology', ' Finance and HR', ' Computer Sciences', ' First Division', ' Information Management', ' Law Enforcement/Criminal Justice', ' Human Resources MSW'], 'Experience': ['System Test Release Coordinator', ' System Test Team Lead', ' System Tester', ' Application System Tester', ' Performing System Test Activities', ' Test Engineer', ' Software Engineer', ' Electrical/Oem Support Engineer', ' Software Engineer firmware', ' Application Design Engineer', ' Oracle DBMS Job Scheduler', ' Resident Engineer Validation Tester', ' Embedded Test Engineer', ' Qa Tester Roles And Responsibilities', ' Software Engineering Qa Analyst', ' Subject Matter Expert']}
# TeamLeader : {'Skills': [['project management'], ['software development'], ['software architecture and design'], ['key account management'], ['customer success'], ['software-as-a-service'], ['client service'], ['business development'], ['renewal management'], ['edi'], ['electronic data interchange'], ['erp systems'], ['file transfer protocol'], ['cobol'], ['edi']], 'Education': ['Geography', ' Information Technology', ' Computer Science', ' Computer Programming', ' Software Engineering', ' Masters Information Technolgy', ' IT Management', ' Economics', ' ITIL Practitioner', ' Server Virtualization'], 'Experience': ['Senior Information Assurance Analyst', ' Information Assurance Analyst', ' Intrusion Prevention System (Ips) Team Technical Lead Supervisor', ' Sr Spatial Data Analyst', ' Director Software Engineering', ' Software Eng Director', ' EDI Systems Analyst', ' EDI Specialist', ' Lead Support Analyst', ' Senior Support Analyst', ' Assistant Front End Manager']}
# NetworkAdministrator : {'Skills': [['ip network address design'], ['cisco routers'], ['cisco ios / cat switches'], ['cisco nexus nx-os switches'], ['wan provisioning'], ['ip routing'], ['atm ox'], ['service provider routing'], ['hsrp'], ['vrrp'], ['glbp'], ['cisco vss'], ['hosted voip'], ['f5 load balancer ltm'], ['juniper srx'], ['mpls and mpls vpn']], 'Education': ['B.S. Economics and Statistics', ' Computer and Information science', ' Computer Information Systems', ' Information Technology'], 'Experience': ['Senior Software Engineer', ' Network Consulting Engineer', ' Sr. Network Engineer', ' Network Infrastructure and VoIP Architect', ' E Commerce Infrastructure Cloud Architect', ' Principal E Commerce Infrastructure Cloud Architect', ' Sr. Enterprise Solutions Infrastructure Architect', ' Sr. Systems Server Engineer', '  \tAdvanced Professional Services Resident Engineer', ' Global Solutions Architect']}
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11084684/206/Information-Technology/Sr-Application-Analyst-14-Years-of-Experience-Near-98312
# Ken K
# ['Occupation: ApplicationSupport', ' Location: Bremerton,WA', ' EducationLevel: Bachelor', ' WillRelocate: No']
# role: WebDeveloper ,score: 7.857142857142857
# role: DataMiningSpecialist ,score: 7.5
# role: DatabaseAdministrator ,score: 10.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 3.6666666666666665
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10915960/512/Information-Technology/System-Engineer-23-Years-of-Experience-Near-78613
# John B
# ['Occupation: ApplicationSupport', ' Location: CedarPark,TX', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 10.857142857142858
# role: DataMiningSpecialist ,score: 32.99999999999999
# role: DatabaseAdministrator ,score: 13.0
# role: Tester ,score: 3.0
# role: TeamLeader ,score: 32.99999999999999
# role: NetworkAdministrator ,score: 3.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10733089/704/Information-Technology/Application-Support-15-Years-of-Experience-Near-28012
# Deanna H
# ['Occupation: ApplicationSupport', ' Location: Belmont,NC', ' EducationLevel: Bachelor', ' WillRelocate: No']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 7.5
# role: DatabaseAdministrator ,score: 7.5
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 7.5
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/9965849/727/Information-Technology/Controller
# Todd V
# ['Occupation: ApplicationSupport', ' Location: Sarasota,FL', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/8953429/404/Information-Technology/Chief-Technology-Officer
# julie s
# ['Occupation: ApplicationSupport', ' Location: NewYork,NY', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 7.5
# role: Tester ,score: 7.5
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/8251463/619/Information-Technology/Senior-Sales-Manager-12-years-Experience-San-Diego
# Jerry C
# ['Occupation: ApplicationSupport', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 11.785714285714285
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 2.5
# role: Tester ,score: 12.941176470588237
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/8208384/240/Information-Technology/-Help-Desk-Support-Security-Certification
# Derwyn D
# ['Occupation: ApplicationSupport', ' Location: TempleHills,MD', ' EducationLevel: Bachelor', ' WillRelocate: No']
# role: WebDeveloper ,score: 3.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 3.0
# role: TeamLeader ,score: 3.0
# role: NetworkAdministrator ,score: 3.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/7994287/760/Information-Technology/Senior-sales-manager
# Alexander H
# ['Occupation: ApplicationSupport', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/7666771/561/Information-Technology/Technology-Director-10-years-Experience-with-a-Platinum-5-Star-Club-in-Boca-Raton-Florida
# Richard G
# ['Occupation: ApplicationSupport', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/7619977/770/Information-Technology/Information-Technology-Support-16-years-Experience-San-Jose-CA-Atlanta-GA
# Zandra C
# ['Occupation: ApplicationSupport', ' EducationLevel: Bachelor', ' WillRelocate: No']
# role: WebDeveloper ,score: 3.0
# role: DataMiningSpecialist ,score: 3.0
# role: DatabaseAdministrator ,score: 3.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 3.0
# role: NetworkAdministrator ,score: 3.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/7056597/617/Information-Technology/Application-Support-5-Years-of-Experience-Near-02126
# Andre J
# ['Occupation: ApplicationSupport', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 15.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/6850315/850/Information-Technology/IT-Manager-and-Site-Lead-11-years-of-leadership-experience
# Fred R
# ['Occupation: ApplicationSupport', ' EducationLevel: TradeSchool', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11074288/651/Information-Technology/IT-Project-Manager-20-Years-of-Experience
# Elizabeth A
# ['Occupation: BusinessAnalyst', ' Location: SaintPaul,MN', ' EducationLevel: Bachelor', ' WillRelocate: No']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 7.5
# role: DatabaseAdministrator ,score: 7.5
# role: Tester ,score: 3.0
# role: TeamLeader ,score: 3.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11008758/646/Information-Technology/Application-Support-20-Years-of-Experience-Near-10280
# Sergei T
# ['Occupation: BusinessAnalyst', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 2.5
# role: Tester ,score: 3.2352941176470593
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10972006/843/Information-Technology/Business-Analyst
# Thomas K
# ['Occupation: BusinessAnalyst', ' Location: Cottageville,SC', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10956317/570/Information-Technology/Project-Management-
# Thomas B
# ['Occupation: BusinessAnalyst', ' EducationLevel: Doctorate', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10925112/770/Information-Technology/Business-Analyst-15-Years-of-Experience-Near-30009
# Margaret N
# ['Occupation: BusinessAnalyst', ' Location: Alpharetta,GA', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 22.499999999999996
# role: DatabaseAdministrator ,score: 22.499999999999996
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 3.6666666666666665
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10852265/864/Information-Technology/Dynamic-IoT-and-Productivity-Engineering-Executive-with-more-than-15-years-of-Product-Development-and-organizational-leadership-experience-saving-more-than-1-8B-in-Productivity-annually-
# Dalero B
# ['Occupation: BusinessAnalyst', ' Location: Atlanta,GA', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 6.0
# role: DataMiningSpecialist ,score: 10.5
# role: DatabaseAdministrator ,score: 3.0
# role: Tester ,score: 6.0
# role: TeamLeader ,score: 28.499999999999996
# role: NetworkAdministrator ,score: 3.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10756055/650/Information-Technology/Business-Analyst
# Erika F
# ['Occupation: BusinessAnalyst', ' Location: RedwoodCity,CA', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10689163/240/Information-Technology/IT-Business-Analyst-Quick-learner-and-ready-for-any-challenge
# HILDA C
# ['Occupation: BusinessAnalyst', ' Location: Germantown,MD', ' EducationLevel: SomeCollegeUnitsCompleted', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 30.0
# role: DatabaseAdministrator ,score: 30.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 22.499999999999996
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10249047/956/Information-Technology/Project-Manager-6-Years-of-Experience-Near-95648
# Frederick M
# ['Occupation: BusinessAnalyst', ' Location: Lincoln,CA', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 3.6666666666666665
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10011778/000/Information-Technology/Business-Analyst-15-Years-of-Experience-Near-91504
# Gerald B
# ['Occupation: BusinessAnalyst', ' Location: Burbank,CA', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/9929746/000/Information-Technology/Business-Analyst-20-Years-of-Experience-Near-27284
# Debra Z
# ['Occupation: BusinessAnalyst', ' Location: Kernersville,NC', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 6.928571428571429
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 15.5
# role: Tester ,score: 3.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 3.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/9847774/770/Information-Technology/Business-Analyst
# David P
# ['Occupation: BusinessAnalyst', ' Location: Lawrenceville,GA', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 3.9285714285714284
# role: DataMiningSpecialist ,score: 18.333333333333336
# role: DatabaseAdministrator ,score: 2.5
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10509339/000/Information-Technology/Business-to-Business-Marketer-19-Years-of-Experience-Near-02180
# Claudine B
# ['Occupation: Business-to-BusinessMarketer', ' Location: Stoneham,MA', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/9039420/000/Information-Technology/Experienced-Federal-IT-Business-Development-Executive-20-Years-of-Experience-Washington-DC-Metro-Area
# LINDA S
# ['Occupation: Business-to-BusinessMarketer', ' EducationLevel: Bachelor', ' WillRelocate: No']
# role: WebDeveloper ,score: 3.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 3.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 3.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11082080/847/Information-Technology/Director-Global-Sales-20-Years-of-Experience-Near-80221
# Jim A
# ['Occupation: Business-to-BusinessMarketer', ' Location: Denver,CO', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 2.5
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 7.5
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10500787/404/Information-Technology/Business-to-Business-Marketer-22-Years-of-Experience-Near-30318
# Karen B
# ['Occupation: Business-to-BusinessMarketer', ' Location: Atlanta,GA', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/7481807/847/Information-Technology/Senior-Sales-Manager-IT-Services-Infrstructure-As-A-Service-Start-Up-Turn-Around-Experience
# Richard C
# ['Occupation: Business-to-BusinessMarketer', ' EducationLevel: SomeCollegeUnitsCompleted', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/7863797/215/Information-Technology/B2B-Marketing-Expert-with-an-Integrated-Approach-10-years-Experience
# Kevin B
# ['Occupation: Business-to-BusinessMarketer', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11058937/801/Information-Technology/Marketing-Chief-Marketing-Officer-High-Growth-Demand-Generation
# Trish S
# ['Occupation: Business-to-BusinessMarketer', ' Location: Syracuse,UT', ' EducationLevel: Bachelor', ' WillRelocate: No']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10887168/612/Information-Technology/Business-to-Business-Marketer
# STEVEN M
# ['Occupation: Business-to-BusinessMarketer', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 7.5
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/4157696/630/Information-Technology/Business-Development-Manager-Custom-Software-Solutions-for-West-Coast-25-states-
# Business Development Manager - Custom Software Solutions for West Coast (25 states)
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10463488/925/Information-Technology/Business-to-Business-Marketer
# Hari D
# ['Occupation: Business-to-BusinessMarketer', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/2957057/713/Information-Technology/Marketing-Campaign-Program-Manager-that-can-drive-revenue-and-quality-sales-leads
# Sue D
# ['Occupation: Business-to-BusinessMarketer', ' Location: Spring,TX', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/996865/222/Information-Technology/Business-to-Business-Marketer
# Rudy R
# ['Occupation: Business-to-BusinessMarketer', ' Location: NorthHydePark,VT', ' EducationLevel: TradeSchool', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/4279742/801/Information-Technology/Mainframe-Production-Control-Clerk-Noc-Center-Analyst-2-Mainframe-Computer-Operator
# woodrow a
# ['Occupation: ComputerOperator', ' Location: Tooele,UT', ' EducationLevel: Associate', ' WillRelocate: No']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 30.0
# role: DatabaseAdministrator ,score: 30.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/3447765/540/Information-Technology/IT-Systems-manager
# Bradley J
# ['Occupation: ComputerOperator', ' Location: Bellingham,WA', ' EducationLevel: Bachelor', ' WillRelocate: No']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 15.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11085003/646/Information-Technology/Computer-Operator
# Shakhzoda T
# ['Occupation: ComputerOperator', ' Location: Chandler,AZ', ' EducationLevel: Associate', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 7.5
# role: DatabaseAdministrator ,score: 7.5
# role: Tester ,score: 7.5
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11084526/847/Information-Technology/Computer-Operator
# Jeff B
# ['Occupation: ComputerOperator', ' EducationLevel: SomeCollegeUnitsCompleted', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 15.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11084379/713/Information-Technology/Computer-Operator-2-Years-of-Experience-Near-77530
# BASIL M
# ['Occupation: ComputerOperator', ' Location: Houston,TX', ' EducationLevel: Associate', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11076195/551/Information-Technology/Computer-Operator
# JOSE M
# ['Occupation: ComputerOperator', ' Location: JerseyCity,NJ', ' EducationLevel: Certification', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11075004/818/Information-Technology/Computer-Operator
# Mayur S
# ['Occupation: ComputerOperator', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11074292/301/Information-Technology/Computer-Operator-20-Years-of-Experience-Near-20723
# john m
# ['Occupation: ComputerOperator', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11073466/612/Information-Technology/Computer-Operator-1-Years-of-Experience-Near-55119
# vinhdat n
# ['Occupation: ComputerOperator', ' EducationLevel: Associate', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 3.2352941176470593
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11072285/469/Information-Technology/Computer-Operator-15-Years-of-Experience-Near-75115
# edgar g
# ['Occupation: ComputerOperator', ' Location: Desoto,TX', ' EducationLevel: SomeCollegeUnitsCompleted', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11070726/301/Information-Technology/Computer-Operator
# Ukpai A
# ['Occupation: ComputerOperator', ' Location: UpperMarlboro,MD', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11068908/828/Information-Technology/Computer-Operator
# Tammie K
# ['Occupation: ComputerOperator', ' EducationLevel: Associate', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11072238/203/Information-Technology/Software-Developer
# Ronald R
# ['Occupation: ComputerProgrammer', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 6.928571428571429
# role: DataMiningSpecialist ,score: 18.0
# role: DatabaseAdministrator ,score: 5.5
# role: Tester ,score: 21.235294117647058
# role: TeamLeader ,score: 6.666666666666667
# role: NetworkAdministrator ,score: 18.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11066106/317/Information-Technology/Computer-Programmer-Over-20-Years-of-Experience-Near-47302
# Ronald P
# ['Occupation: ComputerProgrammer', ' Location: Muncie,IN', ' EducationLevel: SomeCollegeUnitsCompleted', ' WillRelocate: YES']
# role: WebDeveloper ,score: 3.9285714285714284
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 24.999999999999996
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 26.166666666666664
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10834218/917/Information-Technology/Developer
# Richard T
# ['Occupation: ComputerProgrammer', ' Location: StatenIsland,NY', ' EducationLevel: Bachelor', ' WillRelocate: No']
# role: WebDeveloper ,score: 22.642857142857146
# role: DataMiningSpecialist ,score: 3.0
# role: DatabaseAdministrator ,score: 20.5
# role: Tester ,score: 6.470588235294119
# role: TeamLeader ,score: 3.0
# role: NetworkAdministrator ,score: 3.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10678270/443/Information-Technology/Social-media-intern-and-reporter-1-month
# Edem K
# ['Occupation: ComputerProgrammer', ' Location: Towson,MD', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 10.857142857142858
# role: DataMiningSpecialist ,score: 3.0
# role: DatabaseAdministrator ,score: 5.5
# role: Tester ,score: 9.470588235294118
# role: TeamLeader ,score: 3.0
# role: NetworkAdministrator ,score: 3.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10533053/386/Information-Technology/Computer-Programmer-III-3-Years-of-Experience-Near-32763
# Rupal T
# ['Occupation: ComputerProgrammer', ' Location: OrangeCity,FL', ' EducationLevel: Bachelor', ' WillRelocate: No']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 2.5
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10354261/619/Information-Technology/Not-Listed-2-Years-of-Experience-Near-92101
# Jorge L
# ['Occupation: ComputerProgrammer', ' Location: SanDiego,CA', ' EducationLevel: SomeCollegeUnitsCompleted', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 3.2352941176470593
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/7792151/619/Information-Technology/Computer-Programmer-5-years-Experience-san-diego
# Antoinette F
# ['Occupation: ComputerProgrammer', ' EducationLevel: Master', ' WillRelocate: No']
# role: WebDeveloper ,score: 6.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 6.0
# role: Tester ,score: 3.2352941176470593
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 6.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/7492545/916/Information-Technology/Software-Engineer-20-years-experience-Sacramento
# David B
# ['Occupation: ComputerProgrammer', ' EducationLevel: Bachelor', ' WillRelocate: No']
# role: WebDeveloper ,score: 14.428571428571429
# role: DataMiningSpecialist ,score: 3.0
# role: DatabaseAdministrator ,score: 32.99999999999999
# role: Tester ,score: 36.23529411764706
# role: TeamLeader ,score: 3.0
# role: NetworkAdministrator ,score: 3.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11084134/832/Information-Technology/Computer-Programmer
# Denis K
# ['Occupation: ComputerProgrammer', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 15.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11083114/617/Information-Technology/Computer-Programmer
# Ravindra Y
# ['Occupation: ComputerProgrammer', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 13.857142857142858
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 6.0
# role: Tester ,score: 3.2352941176470593
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 6.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11082435/281/Information-Technology/Computer-Programmer-1-Years-of-Experience-Near-77076
# April B
# ['Occupation: ComputerProgrammer', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 3.9285714285714284
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 6.470588235294119
# role: TeamLeader ,score: 3.6666666666666665
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11082320/509/Information-Technology/Computer-Programmer-20-Years-of-Experience-Near-99208
# Gordon C
# ['Occupation: ComputerProgrammer', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 3.2352941176470593
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10489365/740/Information-Technology/Data-Center-Manager-4Years-of-Experience
# Darin S
# ['Occupation: DataCentreManager', ' Location: Conroe,TX', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 30.0
# role: DatabaseAdministrator ,score: 30.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/8465999/262/Information-Technology/Senior-IT-Technology-Management-Professional-9-Years-of-Experience-Near-53186
# David G
# ['Occupation: DataCentreManager', ' EducationLevel: Master', ' WillRelocate: No']
# role: WebDeveloper ,score: 6.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 6.0
# role: TeamLeader ,score: 6.0
# role: NetworkAdministrator ,score: 6.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10641489/678/Information-Technology/Information-Infrastructure-Security-Director
# RAYMOND B
# ['Occupation: DataCentreManager', ' Location: Woodstock,GA', ' EducationLevel: Bachelor', ' WillRelocate: No']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/7097437/512/Information-Technology/Customer-Support-Supervisor-II-Service-Manager-level-2-Support-Team-Help-desk-Manager
# Dudley L
# ['Occupation: DataCentreManager', ' EducationLevel: Associate', ' WillRelocate: YES']
# role: WebDeveloper ,score: 3.9285714285714284
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 30.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/3278080/918/Information-Technology/Experienced-Manager-Senior-Manager-People-Project-Program
# Experienced Manager / Senior Manager: People, Project, Program
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/3645952/770/Information-Technology/Data-Center-Operations-Supervisor-27-years-experience-Mainframe-Operations-and-larger-Server-operations-and-AS400
# Data Center Operations Supervisor- 27 years experience Mainframe Operations and larger Server operations and AS400
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10521601/215/Information-Technology/Data-Centre-Manager-19-Years-of-Experience-Near-19050
# James T
# ['Occupation: DataCentreManager', ' Location: Lansdowne,PA', ' EducationLevel: HighSchool/GED', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/6468097/847/Information-Technology/Data-Centre-Manager
# Data Centre Manager
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/4076290/919/Information-Technology/Data-Centre-Manager
# Data Centre Manager
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/8343810/703/Information-Technology/Data-Centre-Manager-20-Years-of-Experience-Near-78745
# Cynthia J
# ['Occupation: DataCentreManager', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/3106050/916/Information-Technology/Data-Centre-Manager
# Data Centre Manager
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/8398851/703/Information-Technology/Data-Centre-Manager-20-Years-of-Experience
# Donald W
# ['Occupation: DataCentreManager', ' EducationLevel: SomeCollegeUnitsCompleted', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10935309/978/Information-Technology/Data-Mining-Specialist
# Brendan G
# ['Occupation: DataMiningSpecialist', ' Location: Washington,DC', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 2.5
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10683792/936/Information-Technology/Not-Listed-21-Years-of-Experience-Near-76108
# David B
# ['Occupation: DataMiningSpecialist', ' Location: FortWorth,TX', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 36.0
# role: DataMiningSpecialist ,score: 6.0
# role: DatabaseAdministrator ,score: 6.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 6.0
# role: NetworkAdministrator ,score: 6.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10614935/847/Information-Technology/Digital-forensic-analyst
# Ronnie R
# ['Occupation: DataMiningSpecialist', ' Location: Evanston,IL', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 22.499999999999996
# role: DatabaseAdministrator ,score: 7.5
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 7.5
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10489500/610/Information-Technology/Data-Mining-Specialist-20-Years-of-Experience-Near-19341
# Gerald L
# ['Occupation: DataMiningSpecialist', ' Location: WestChester,PA', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 22.499999999999996
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 7.5
# role: NetworkAdministrator ,score: 7.5
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10469870/917/Information-Technology/Data-Mining-Specialist
# Alexander D
# ['Occupation: DataMiningSpecialist', ' EducationLevel: Doctorate', ' WillRelocate: YES']
# role: WebDeveloper ,score: 3.9285714285714284
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 3.2352941176470593
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10201261/301/Information-Technology/Data-Mining-Specialist-12-Years-of-Experience-Near-20876
# EDGAR N
# ['Occupation: DataMiningSpecialist', ' Location: Germantown,MD', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 3.2352941176470593
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11083591/310/Information-Technology/Data-Mining-Specialist
# TRACY M
# ['Occupation: DataMiningSpecialist', ' EducationLevel: Associate', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 2.5
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11082629/865/Information-Technology/Data-Mining-Specialist-4-Years-of-Experience
# Jiyuan Z
# ['Occupation: DataMiningSpecialist', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 7.5
# role: DatabaseAdministrator ,score: 7.5
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11081393/224/Information-Technology/Data-Mining-Specialist
# SANTHIMA P
# ['Occupation: DataMiningSpecialist', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 15.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11081176/925/Information-Technology/Data-Mining-Specialist
# Ramesh K
# ['Occupation: DataMiningSpecialist', ' EducationLevel: Doctorate', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11075046/203/Information-Technology/Data-Mining-Specialist
# Lucas L
# ['Occupation: DataMiningSpecialist', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 2.5
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11073683/214/Information-Technology/Data-Mining-Specialist
# Craig L
# ['Occupation: DataMiningSpecialist', ' EducationLevel: Associate', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 2.5
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11070187/901/Information-Technology/Database-Administrator
# Tony H
# ['Occupation: DatabaseAdministrator', ' Location: Memphis,TN', ' EducationLevel: Associate', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11049963/608/Information-Technology/Database-Administrator-15-Years-of-Experience-Near-53593
# Gill R
# ['Occupation: DatabaseAdministrator', ' Location: Verona,WI', ' EducationLevel: Associate', ' WillRelocate: YES']
# role: WebDeveloper ,score: 3.9285714285714284
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 2.5
# role: Tester ,score: 3.2352941176470593
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# ...
# Alexander L
# ['Occupation: TelecommSpecialist', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 2.5
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/8427929/630/Information-Technology/Tester-15-Years-of-Experience-Near-60473
# Ade O
# ['Occupation: Tester', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 6.0
# role: Tester ,score: 7.5
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 6.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/4538505/703/Information-Technology/ESL-tester-over-30-years-overseas-and-the-U-S-A-
# Abdulqadir R
# ['Occupation: Tester', ' Location: Centreville,VA', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11085178/832/Information-Technology/Tester
# Javahir J
# ['Occupation: Tester', ' Location: Conroe,TX', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11082451/240/Information-Technology/Tester
# Ayna D
# ['Occupation: Tester', ' Location: Washington,DC', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 15.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 3.2352941176470593
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11079905/773/Information-Technology/Tester
# Vitaliy S
# ['Occupation: Tester', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 7.5
# role: DatabaseAdministrator ,score: 5.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 7.5
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11078977/508/Information-Technology/Tester
# shalma S
# ['Occupation: Tester', ' Location: SouthGrafton,MA', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11078083/770/Information-Technology/Tester
# Robyn R
# ['Occupation: Tester', ' Location: Alpharetta,GA', ' EducationLevel: HighSchool/GED', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11077517/929/Information-Technology/Tester
# Yusuf A
# ['Occupation: Tester', ' Location: DesPlaines,IL', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 7.5
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 3.2352941176470593
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11075336/972/Information-Technology/Tester
# Tressie C
# ['Occupation: Tester', ' EducationLevel: SomeCollegeUnitsCompleted', ' WillRelocate: YES']
# role: WebDeveloper ,score: 3.9285714285714284
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 2.5
# role: Tester ,score: 30.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11073200/715/Information-Technology/Tester-20-Years-of-Experience-Near-89144
# connie k
# ['Occupation: Tester', ' Location: LasVegas,NV', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 15.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11071898/678/Information-Technology/Tester
# Nilanjana D
# ['Occupation: Tester', ' Location: Marietta,GA', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 7.5
# role: TeamLeader ,score: 7.5
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11071836/858/Information-Technology/Tester
# David B
# ['Occupation: Tester', ' Location: SanDiego,CA', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 15.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 15.0
# role: TeamLeader ,score: 15.0
# role: NetworkAdministrator ,score: 15.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10970335/347/Information-Technology/Web-Developer-1-Years-of-Experience-Near-11207
# Carden P
# ['Occupation: WebDeveloper', ' Location: Brooklyn,NY', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 31.071428571428573
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 5.0
# role: Tester ,score: 6.235294117647059
# role: TeamLeader ,score: 32.99999999999999
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/9785366/422/Information-Technology/Web-Developer-7-Years-of-Experience-Near-92101
# Mingle T
# ['Occupation: WebDeveloper', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/8037579/603/Information-Technology/Web-Development-Professional-1-years-experience-Drupal-Microsoft-SharePoint
# Tyler H
# ['Occupation: WebDeveloper', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 14.428571428571429
# role: DataMiningSpecialist ,score: 3.0
# role: DatabaseAdministrator ,score: 3.0
# role: Tester ,score: 3.0
# role: TeamLeader ,score: 3.0
# role: NetworkAdministrator ,score: 3.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/2686375/619/Information-Technology/Web-Developer
# Web Developer
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11084032/602/Information-Technology/Web-Developer
# Duy L
# ['Occupation: WebDeveloper', ' Location: Phoenix,AZ', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 11.785714285714285
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 7.5
# role: Tester ,score: 3.2352941176470593
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11083440/310/Information-Technology/Web-Developer
# Dave C
# ['Occupation: WebDeveloper', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 15.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11082417/908/Information-Technology/Web-Developer
# Hiten V
# ['Occupation: WebDeveloper', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 30.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 32.5
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11082088/630/Information-Technology/Web-Developer
# Ovidiu B
# ['Occupation: WebDeveloper', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11081905/898/Information-Technology/Web-Developer
# SHWETA T
# ['Occupation: WebDeveloper', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 7.5
# role: DataMiningSpecialist ,score: 7.5
# role: DatabaseAdministrator ,score: 10.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 7.5
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11081286/832/Information-Technology/Web-Developer
# Kabir R
# ['Occupation: WebDeveloper', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 7.5
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11079131/916/Information-Technology/Web-Developer
# Rocky C
# ['Occupation: WebDeveloper', ' Location: WestSacramento,CA', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 3.9285714285714284
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 3.2352941176470593
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/11078906/571/Information-Technology/Web-Developer
# Venkata sesha lalitha K
# ['Occupation: WebDeveloper', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 13.5
# role: DataMiningSpecialist ,score: 7.5
# role: DatabaseAdministrator ,score: 6.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 6.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/3464192/719/Information-Technology/Junior-Web-Administrator-2-years-SharePoint-IIS6-0-7-0
# Junior Web Administrator - 2 years - SharePoint - IIS6.0,7.0
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/8870657/816/Information-Technology/Webmaster
# Joseph M
# ['Occupation: Webmaster', ' Location: KansasCity,MO', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/1626625/832/Information-Technology/When-you-need-to-get-projects-done-contact-me-
# Alan P
# ['Occupation: Webmaster', ' Location: Houston,TX', ' EducationLevel: Associate', ' WillRelocate: No']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 2.5
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/3463938/646/Information-Technology/Webmaster-IT-technician
# Webmaster, IT technician
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/8218884/832/Information-Technology/Webmaster-2-Years-of-Experience-Near-77299
# Peter L
# ['Occupation: Webmaster', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/142853/813/Information-Technology/Experienced-and-highly-motivated-professional
# Dana C
# ['Occupation: Webmaster', ' Location: Beacon,NY', ' EducationLevel: Associate', ' WillRelocate: YES']
# role: WebDeveloper ,score: 7.857142857142857
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 2.5
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/1088005/404/Information-Technology/Webmaster
# Manoj K. S
# ['Occupation: Webmaster', ' Location: Syracuse,NY', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/10557702/573/Information-Technology/Webmaster
# Sonia K
# ['Occupation: Webmaster', ' EducationLevel: Master', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/4473862/319/Information-Technology/Web-Designer-Iowa
# Web Designer, Iowa
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/317191/585/Information-Technology/Willing-to-work-
# Tabitha K
# ['Occupation: Webmaster', ' Location: Brockport,NY', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/2613255/931/Information-Technology/Webmaster
# Joseph C
# ['Occupation: Webmaster', ' Location: Waverly,TN', ' EducationLevel: HighSchool/GED', ' WillRelocate: YES']
# role: WebDeveloper ,score: 0.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 0.0
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 0.0
# role: NetworkAdministrator ,score: 0.0
# *********
# https://members.climber.com/online-resumes/pdf-doc-txt-rtf-resume/196873/717/Information-Technology/Webmaster
# Crystal S
# ['Occupation: Webmaster', ' Location: Allentown,PA', ' EducationLevel: Bachelor', ' WillRelocate: YES']
# role: WebDeveloper ,score: 3.0
# role: DataMiningSpecialist ,score: 0.0
# role: DatabaseAdministrator ,score: 2.5
# role: Tester ,score: 0.0
# role: TeamLeader ,score: 3.0
# role: NetworkAdministrator ,score: 3.0
